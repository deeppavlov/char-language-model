# %%
mypath = 'random_choice_report/random_choice/text_plots'
import os
from os import listdir
from os.path import isfile, join
dir_list = listdir(mypath)
for directory in dir_list:
    file_list = listdir(mypath + '/' + directory)
    print(file_list)
    for file_name in file_list[3:]:
        os.remove(mypath + '/' + directory + '/' + file_name)
# Out:
# ['ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#24.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#10.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#16.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#11.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#34.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#47.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#38.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#44.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#37.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#22.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#29.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#9.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#42.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#45.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#27.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#31.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#26.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#4.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#43.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#33.png', 'ns20k_th0.5_ib0_sw0.2_sp-0.26_mf0.01#13.png', 'ns20k_th0.5
# ...
