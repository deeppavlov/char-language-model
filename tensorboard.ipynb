# %%
from tensorflow.tensorboard.backend.event_processing import event_accumulator

# %%
import os

folder = '/home/anton/Natural-language-encoding/HM_LSTM_res/server/HM_LSTM3/clean1/logging/first_log'
file = 'events.out.tfevents.1502033308.node16'
print(os.path.isfile(folder + '/' + file))
ea = event_accumulator.EventAccumulator(folder + '/' + file)
# Out:
# True

# %%
print(ea.Tags())
ea.Reload()
ea.Scalars('output_bias_sum')
# Out:
# {'tensors': [], 'audio': [], 'compressedHistograms': [], 'run_metadata': [], 'images': [], 'scalars': [], 'histograms': [], 'meta_graph': False, 'graph': False}
# [ScalarEvent(wall_time=1502033445.7761834, step=5, value=0.02720794640481472),
#  ScalarEvent(wall_time=1502033447.408585, step=7, value=0.03453714773058891),
#  ScalarEvent(wall_time=1502033454.091983, step=15, value=0.05331256613135338),
#  ScalarEvent(wall_time=1502033454.8970115, step=16, value=0.055127937346696854),
#  ScalarEvent(wall_time=1502033458.9252238, step=21, value=0.062496721744537354),
#  ScalarEvent(wall_time=1502033459.7253048, step=22, value=0.06361320614814758),
#  ScalarEvent(wall_time=1502033460.5181751, step=23, value=0.06462908536195755),
#  ScalarEvent(wall_time=1502033464.7076874, step=28, value=0.06939814239740372),
#  ScalarEvent(wall_time=1502033466.3128955, step=30, value=0.07136840373277664),
#  ScalarEvent(wall_time=1502033472.069336, step=37, value=0.07630101591348648),
# ...
