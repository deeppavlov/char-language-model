# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import random
import string
import tensorflow as tf
from tensorflow.python.ops.rnn_cell import _linear
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve
import collections
import matplotlib.pyplot as plt
import codecs
import time
import os
import gc
from six.moves import cPickle as pickle

from plot_module import text_plot
from plot_module import structure_vocabulary_plots
from plot_module import ComparePlots

from model_module import maybe_download
from model_module import read_data
from model_module import check_not_one_byte
from model_module import id2char
from model_module import char2id
from model_module import BatchGenerator
from model_module import characters
from model_module import batches2string
from model_module import logprob
from model_module import sample_distribution
from model_module import MODEL

# %%
if not os.path.exists('enwik8_filtered'):
    if not os.path.exists('enwik8'):
        filename = maybe_download('enwik8.zip', 36445475)
    full_text = read_data(filename)
    new_text = u""
    new_text_list = list()
    for i in range(len(full_text)):
        if (i+1) % 10000000 == 0:
            print("%s characters are filtered" % i)
        if ord(full_text[i]) < 256:
            new_text_list.append(full_text[i])
    text = new_text.join(new_text_list)
    del new_text_list
    del new_text
    del full_text

    (not_one_byte_counter, min_character_order_index, max_character_order_index, number_of_characters, present_characters_indices) = check_not_one_byte(text)

    print("number of not one byte characters: ", not_one_byte_counter) 
    print("min order index: ", min_character_order_index)
    print("max order index: ", max_character_order_index)
    print("total number of characters: ", number_of_characters)
    
    f = open('enwik8_filtered', 'w')
    f.write(text.encode('utf8'))
    f.close()
    
else:
    f = open('enwik8_filtered', 'r')
    text = f.read().decode('utf8')
    f.close() 
    (not_one_byte_counter, min_character_order_index, max_character_order_index, number_of_characters, present_characters_indices) = check_not_one_byte(text)

    print("number of not one byte characters: ", not_one_byte_counter) 
    print("min order index: ", min_character_order_index)
    print("max order index: ", max_character_order_index)
    print("total number of characters: ", number_of_characters)
# Out:
# number of not one byte characters:  0
# min order index:  9
# max order index:  255
# total number of characters:  196

# %%
#different
offset = 30000
valid_size = 25000
valid_text = text[offset:offset+valid_size]
train_text = text[offset+valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99325000 c facade.&lt;ref&gt;[http://library.nothingness.org/articles/SI/
# 25000 n in the February 1934 riots, anarchists divided over a 'united

# %%
#different
offset_1 = 0
offset_2 = 4100
valid_size_1 = 4000
valid_size_2 = 4000
valid_text_1 = text[offset_1:offset_1+valid_size_1]
valid_text_2 = text[offset_2:offset_2+valid_size_2]
train_text = text[offset_2+valid_size_2:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size_1, valid_text_1[:64])
print(valid_size_2, valid_text_2[:64])
print(valid_text_1)
print('\n\n\n')
print(valid_text_2)
# Out:
# 99371900 , Zeno &quot;repudiated the omnipotence of the state, its interv
# 4000 <mediawiki xmlns="http://www.mediawiki.org/xml/export-0.3/" xmln
# 4000 reserve">{{Anarchism}}
# '''Anarchism''' originated as a term of a
# <mediawiki xmlns="http://www.mediawiki.org/xml/export-0.3/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.mediawiki.org/xml/export-0.3/ http://www.mediawiki.org/xml/export-0.3.xsd" version="0.3" xml:lang="en">
#   <siteinfo>
#     <sitename>Wikipedia</sitename>
#     <base>http://en.wikipedia.org/wiki/Main_Page</base>
#     <generator>MediaWiki 1.6alpha</generator>
#     <case>first-letter</case>
#       <namespaces>
#       <namespace key="-2">Media</namespace>
#       <namespace key="-1">Special</namespace>
#       <namespace key="0" />
#       <namespace key="1">Talk</namespace>
#       <namespace key="2">User</namespace>
#       <namespace key="3">User talk</namespace>
#       <namespace key="4">Wikipedia</namespace>
#       <namespace key="5">Wikipedia talk</namespace>
#       <namespace key="6">Image</namespace>
#       <namespace key="7">Image talk</namespace>
#       <namespace key="8">MediaWiki</namespace>
#       <namespace key="9">MediaWiki talk</namespace>
#       <namespace key="10">Template</namespace>
#       <namespace key="11">Template talk</namespace>
#       <namespace key="12">Help</namespace>
#       <namespace key="13">Help talk</namespace>
#       <namespace key="14">Category</namespace>
#       <namespace key="15">Category talk</namespace>
#       <namespace key="100">Portal</namespace>
#       <namespace key="101">Portal talk</namespace>
#     </namespaces>
#   </siteinfo>
#   <page>
#     <title>AaA</title>
#     <id>1</id>
#     <revision>
#       <id>32899315</id>
#       <timestamp>2005-12-27T18:46:47Z</timestamp>
#       <contributor>
#         <username>Jsmethers</username>
#         <id>614213</id>
#       </contributor>
#       <text xml:space="preserve">#REDIRECT [[AAA]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>AlgeriA</title>
#     <id>5</id>
#     <revision>
#       <id>18063769</id>
#       <timestamp>2005-07-03T11:13:13Z</timestamp>
#       <contributor>
#         <username>Docu</username>
#         <id>8029</id>
#       </contributor>
#       <minor />
#       <comment>adding cur_id=5: {{R from CamelCase}}</comment>
#       <text xml:space="preserve">#REDIRECT [[Algeria]]{{R from CamelCase}}</text>
#     </revision>
#   </page>
#   <page>
#     <title>AmericanSamoa</title>
#     <id>6</id>
#     <revision>
#       <id>18063795</id>
#       <timestamp>2005-07-03T11:14:17Z</timestamp>
#       <contributor>
#         <username>Docu</username>
#         <id>8029</id>
#       </contributor>
#       <minor />
#       <comment>adding to cur_id=6  {{R from CamelCase}}</comment>
#       <text xml:space="preserve">#REDIRECT [[American Samoa]]{{R from CamelCase}}</text>
#     </revision>
#   </page>
#   <page>
#     <title>AppliedEthics</title>
#     <id>8</id>
#     <revision>
#       <id>15898943</id>
#       <timestamp>2002-02-25T15:43:11Z</timestamp>
#       <contributor>
#         <ip>Conversion script</ip>
#       </contributor>
#       <minor />
#       <comment>Automated conversion</comment>
#       <text xml:space="preserve">#REDIRECT [[Applied ethics]]
# </text>
#     </revision>
#   </page>
#   <page>
#     <title>AccessibleComputing</title>
#     <id>10</id>
#     <revision>
#       <id>15898945</id>
#       <timestamp>2003-04-25T22:18:38Z</timestamp>
#       <contributor>
#         <username>Ams80</username>
#         <id>7543</id>
#       </contributor>
#       <minor />
#       <comment>Fixing redirect</comment>
#       <text xml:space="preserve">#REDIRECT [[Accessible_computing]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>AdA</title>
#     <id>11</id>
#     <revision>
#       <id>15898946</id>
#       <timestamp>2002-09-22T16:02:58Z</timestamp>
#       <contributor>
#         <username>Andre Engels</username>
#         <id>300</id>
#       </contributor>
#       <minor />
#       <text xml:space="preserve">#REDIRECT [[Ada programming language]]</text>
#     </revision>
#   </page>
#   <page>
#     <title>Anarchism</title>
#     <id>12</id>
#     <revision>
#       <id>42136831</id>
#       <timestamp>2006-03-04T01:41:25Z</timestamp>
#       <contributor>
#         <username>CJames745</username>
#         <id>832382</id>
#       </contributor>
#       <min
#
#
#
#
# reserve">{{Anarchism}}
# '''Anarchism''' originated as a term of abuse first used against early [[working class]] [[radical]]s including the [[Diggers]] of the [[English Revolution]] and the [[sans-culotte|''sans-culottes'']] of the [[French Revolution]].[http://uk.encarta.msn.com/encyclopedia_761568770/Anarchism.html] Whilst the term is still used in a pejorative way to describe ''&quot;any act that used violent means to destroy the organization of society&quot;''&lt;ref&gt;[http://www.cas.sc.edu/socy/faculty/deflem/zhistorintpolency.html History of International Police Cooperation], from the final protocols of the &quot;International Conference of Rome for the Social Defense Against Anarchists&quot;, 1898&lt;/ref&gt;, it has also been taken up as a positive label by self-defined anarchists.
#
# The word '''anarchism''' is [[etymology|derived from]] the [[Greek language|Greek]] ''[[Wiktionary:&amp;#945;&amp;#957;&amp;#945;&amp;#961;&amp;#967;&amp;#943;&amp;#945;|&amp;#945;&amp;#957;&amp;#945;&amp;#961;&amp;#967;&amp;#943;&amp;#945;]]'' (&quot;without [[archon]]s (ruler, chief, king)&quot;). Anarchism as a [[political philosophy]], is the belief that ''rulers'' are unnecessary and should be abolished, although there are differing interpretations of what this means. Anarchism also refers to related [[social movement]]s) that advocate the elimination of authoritarian institutions, particularly the [[state]].&lt;ref&gt;[http://en.wikiquote.org/wiki/Definitions_of_anarchism Definitions of anarchism] on Wikiquote, accessed 2006&lt;/ref&gt; The word &quot;[[anarchy]],&quot; as most anarchists use it, does not imply [[chaos]], [[nihilism]], or [[anomie]], but rather a harmonious [[anti-authoritarian]] society. In place of what are regarded as authoritarian political structures and coercive economic institutions, anarchists advocate social relations based upon [[voluntary association]] of autonomous individuals, [[mutual aid]], and [[self-governance]].
#
# While anarchism is most easily defined by what it is against, anarchists also offer positive visions of what they believe to be a truly free society. However, ideas about how an anarchist society might work vary considerably, especially with respect to economics; there is also disagreement about how a free society might be brought about.
#
# == Origins and predecessors ==
#
# [[Peter Kropotkin|Kropotkin]], and others, argue that before recorded [[history]], human society was organized on anarchist principles.&lt;ref&gt;[[Peter Kropotkin|Kropotkin]], Peter. ''&quot;[[Mutual Aid: A Factor of Evolution]]&quot;'', 1902.&lt;/ref&gt; Most anthropologists follow Kropotkin and Engels in believing that hunter-gatherer bands were egalitarian and lacked division of labour, accumulated wealth, or decreed law, and had equal access to resources.&lt;ref&gt;[[Friedrich Engels|Engels]], Freidrich. ''&quot;[http://www.marxists.org/archive/marx/works/1884/origin-family/index.htm Origins of the Family, Private Property, and the State]&quot;'', 1884.&lt;/ref&gt;
# [[Image:WilliamGodwin.jpg|thumb|right|150px|William Godwin]]
#
# Anarchists including the [[The Anarchy Organisation]] and [[Murray Rothbard|Rothbard]] find anarchist attitudes in [[Taoism]] from [[History of China|Ancient China]].&lt;ref&gt;The Anarchy Organization (Toronto). ''Taoism and Anarchy.'' [[April 14]] [[2002]] [http://www.toxicpop.co.uk/library/taoism.htm Toxicpop mirror] [http://www.geocities.com/SoHo/5705/taoan.html Vanity site mirror]&lt;/ref&gt;&lt;ref&gt;[[Murray Rothbard|Rothbard]], Murray. ''&quot;[http://www.lewrockwell.com/rothbard/ancient-chinese.html The Ancient Chinese Libertarian Tradition]&quot;'', an extract from ''&quot;[http://www.mises.org/journals/jls/9_2/9_2_3.pdf Concepts of the Role of Intellectuals in Social Change Toward Laissez Faire]&quot;'', The Journal of Libertarian Studies, 9 (2) Fall 1990.&lt;/ref&gt; [[Peter Kropotkin|Kropotkin]] found similar ideas in [[stoicism|stoic]] [[Zeno of Citium]]. According to Kropotkin

# %%
vocabulary_size = number_of_characters
vocabulary = list()
characters_positions_in_vocabulary = list()

character_position_in_vocabulary = 0
for i in range(256):
    if present_characters_indices[i]:
        vocabulary.append(unichr(i))
        characters_positions_in_vocabulary.append(character_position_in_vocabulary)
        character_position_in_vocabulary += 1
    else:
        characters_positions_in_vocabulary.append(-1)


string_vocabulary = u""
for i in range(vocabulary_size):
    string_vocabulary += vocabulary[i]
print("Vocabulary: ", string_vocabulary)
print("char2id(u'a') = %s,  char2id(u'z') = %s,  char2id(u' ') = %s" % (char2id(u'a', characters_positions_in_vocabulary),
                                                                        char2id(u'z', characters_positions_in_vocabulary),
                                                                        char2id(u' ', characters_positions_in_vocabulary)))
print("id2char(78) = %s,  id2char(156) = %s,  id2char(140) = %s" % (id2char(78,
                                                                            vocabulary),
                                                                    id2char(156,
                                                                            vocabulary),
                                                                    id2char(140,
                                                                            vocabulary)))
# Out:
# Vocabulary:
#  !"#$%&'()*+,-./0123456789:;<=>?@ABCDEFGHIJKLMNOPQRSTUVWXYZ[\]^_`abcdefghijklmnopqrstuvwxyz{|}~ ¡¢£¤¥¦§¨©ª«¬­®¯°±²³´µ¶·¸¹º»¼½¾¿ÀÁÂÃÄÅÆÇÈÉÊËÌÍÎÏÐÑÒÓÔÕÖ×ØÙÚÛÜÝÞßàáâãäåæçèéêëìíîïðñòóôõö÷øùúûüýþÿ
# char2id(u'a') = 67,  char2id(u'z') = 92,  char2id(u' ') = 2
# id2char(78) = l,  id2char(156) = Ø,  id2char(140) = È

# %%
batch_size_test=64
num_unrollings_test=10

train_batches_test = BatchGenerator(train_text,
                                    batch_size_test,
                                    vocabulary_size,
                                    characters_positions_in_vocabulary,
                                    num_unrollings_test)
valid_batches_test = BatchGenerator(valid_text_1,
                                    1,
                                    vocabulary_size,
                                    characters_positions_in_vocabulary,
                                    1)

print(batches2string(train_batches_test.next(), vocabulary))
print(batches2string(train_batches_test.next(), vocabulary))
print(batches2string(valid_batches_test.next(), vocabulary))
print(batches2string(valid_batches_test.next(), vocabulary))
# Out:
# [u', Zeno &quo', u'act science', u'] systems. ', u"* ''Women E", u'nis. It ori', u'ilanthus al', u'ave diminis', u't;Advance A', u'orded in ce', u' late [[179', u'. A strong ', u'bodia]] led', u'f the Hill]', u']] | above=', u"t rather ''", u"d 'Babe Rut", u'[Chicago Wh', u'overed to b', u'when he spr', u' search].\n*', u'erminology=', u'ile.\n\n====1', u'ife and car', u'509</id>\n  ', u' featured i', u'other marin', u'ere has bee', u' be copied ', u' subdivisio', u'eased drawi', u'include:\n\n[', u'for the thi', u'age do not ', u'ion>\n      ', u'(book)|Drag', u': ([[1921]]', u'ndia in ord', u'how can we ', u'</timestamp', u's and also ', u'n ==\nThe Es', u'nredlist.or', u' fully or p', u'ma was revi', u'ometimes &l', u'when there ', u' and [[pena', u'arkets (see', u'uage with t', u'the [[Ameri', u'lable power', u'ername>\n   ', u'phen]]s in ', u'ws and the ', u' culture ha', u'uardians of', u'llaboration', u'ot;Lords of', u' Howard, 3r', u'ersonnel ca', u' drafts [[l', u'edarville, ', u'NA)&lt;/TD&', u'rraced agri']
# [u'ot;repudiat', u'e, deductiv', u' He also wo', u"Encamping''", u'iginates at', u'ltissima1.j', u'shed in imp', u'Australia f', u'ertain sect', u'92]] Philli', u' ballad wit', u'd by [[Pol ', u']] was crea', u'=- | below=', u"'apostolic ", u"th', see [[", u'hite Sox]]&', u'be 99% simi', u'reads money', u'* [http://w', u'==\n[[Image:', u'19781990===', u'reer]\n*[htt', u'     <times', u'in many fil', u'nas and boa', u'en an exten', u' to the pri', u"on = \n''Vac", u'ing and dec', u'[[Prophecy]', u'ird derivat', u' have a [[s', u' <id>159063', u"gonology]]'", u"]): &quot;'", u'der to argu', u' distinguis', u'p>\n      <c', u' local hous', u'ssenes are ', u'rg&gt;. Dow', u'partly porn', u'italized in', u'lt;math&gt;', u' is an equi', u'alty shooto', u'e [[economi', u'the earlies', u'ican Marcon', u'r ups. Whil', u'      <id>6', u' place of a', u' survival o', u'ad spread a', u'f Scotland ', u'n with UMNO', u'f Parliamen', u'rd Duke of ', u'arrier]] (A', u'legislation', u' Indiana|Le', u'&gt;\n    &l', u'iculture th']
# [u'<m']
# [u'me']

# %%
class ACT_LSTM_individual(MODEL):
    
    def LSTM_cell(self, inp, state):
        #print('inp.shape: ', inp.get_shape().as_list())
        #print('state[0].shape: ', state[0].get_shape().as_list())
        X = tf.concat(1, [inp,
                          state[0]])
        concat = tf.matmul(X, self.Matrix) + self.Bias
        [i, f, o, g] = tf.split(1, 4, concat)
        i = tf.sigmoid(i)
        f = tf.sigmoid(f)
        o = tf.sigmoid(o)
        g = tf.tanh(g)
        new_state = tf.tanh(i*g+f*state[1])
        output = o * new_state 
        return [output, new_state]
    
    def add_flag_to_input(self, X, idx):
        flags = list()
        one_flag = [0.]*self._depth
        one_flag[idx] = 1.
        flag = tf.pack([tf.constant(one_flag)] * X.get_shape().as_list()[0])
        return tf.concat(1, [X, flag])
    
    def compute_halting_units(self, intermediate_states):
        states_concat = tf.concat(0, [tf.concat(1, [state[0], state[1]]) for state in intermediate_states])
        halting_units = tf.sigmoid(tf.matmul(states_concat, self.Halting_Matrix) + self.Halting_Bias)
        return tf.split(0, len(intermediate_states), halting_units)
        
    
    def compute_probabilities(self, halting_units):
        b_size = halting_units[0].get_shape().as_list()[0]
        agregate = tf.zeros([b_size, self._num_nodes[0]])
        completed = tf.zeros([b_size, self._num_nodes[0]])
        ones = tf.ones([b_size, self._num_nodes[0]])
        minus_ones = - ones
        probabilities = list()
        prob_loss = 0
        for idx, halting_unit in enumerate(halting_units):
            if idx == self._depth - 1:
                completed_flags = tf.to_float(tf.greater(agregate, -0.5))
            else:
                completed_flags = tf.to_float(tf.greater(agregate + halting_unit, self._threshold))
            completed += completed_flags
            probabilities.append((ones - completed) * halting_unit + completed_flags * (ones - agregate))
            prob_loss += tf.reduce_sum(completed_flags * (ones - agregate))
            agregate = minus_ones * completed + (ones - completed) * (agregate + halting_unit)
        return probabilities, prob_loss
            
    def compute_number_of_iterations(self, probabilities):
        probs = tf.pack(probabilities, axis=2)
        looped = tf.greater(probs, 0)
        looped = tf.to_int32(looped)
        return tf.reduce_sum(looped, reduction_indices=[2])
               
    
    def iteration(self, inp, old_state):
        """print('is_list: ', isinstance(old_state, list))
        if isinstance(old_state, list):
            print('old_state[0].shape: ', old_state[0].get_shape().as_list())
        else:
            print('old_state.shape: ', old_state.get_shape().as_list())"""
        b_size = inp.get_shape().as_list()[0]
        intermediate_states = list()
        halting_units = list()
        agregate = tf.zeros([b_size, self._num_nodes[0]])
        ones = tf.ones([b_size, self._num_nodes[0]])
        for idx in range(self._depth):
            new_state = self.LSTM_cell(self.add_flag_to_input(inp, idx), old_state)
            mask = tf.to_float(tf.less(agregate, self._threshold))
            very_old_state = old_state
            old_state = list()
            old_state.append(mask * new_state[0] + (ones - mask) * very_old_state[0])
            old_state.append(mask * new_state[1] + (ones - mask) * very_old_state[1])
            halting_unit = tf.sigmoid(tf.matmul(tf.concat(1, old_state), self.Halting_Matrix) + self.Halting_Bias)
            agregate += halting_unit
            halting_units.append(halting_unit)
            intermediate_states.append(old_state)
        probabilities, prob_loss = self.compute_probabilities(halting_units)
        number_of_iterations = self.compute_number_of_iterations(probabilities)
        new_state = [0, 0]
        for inter_state, probability in zip(intermediate_states, probabilities):
            new_state[0] +=  inter_state[0] * probability
            new_state[1] +=  inter_state[1] * probability
        return new_state[0], new_state, prob_loss, number_of_iterations, probabilities, halting_units

    
    def __init__(self,
                 batch_size,
                 vocabulary,
                 characters_positions_in_vocabulary,
                 num_unrollings,
                 num_nodes,
                 depth,
                 indent,
                 time_penalty,
                 train_text,
                 valid_text,
                 mean=0.,
                 stddev='default',
                 shift=0.,
                 init_learning_rate=5.):
        self._results = list()
        self._batch_size = batch_size
        self._vocabulary = vocabulary
        self._vocabulary_size = len(vocabulary)
        self._characters_positions_in_vocabulary = characters_positions_in_vocabulary
        
        self._num_unrollings = num_unrollings

        self._num_layers = 1
        self._num_nodes = num_nodes
        self._depth = depth
        self._indent = indent
        self._time_penalty = time_penalty
        self._threshold = 1. - indent
        self._train_text = train_text
        self._valid_text = valid_text
        if isinstance(self._valid_text, dict):
            keys = self._valid_text.keys()
            self._valid_size = dict([zipped for zipped in zip(keys, [len(self._valid_text[key]) for key in keys])])
        else:
            self._valid_size = len(valid_text)
        
        
        self._mean = mean
        
        self._shift = shift
        
        self._stddev = list()
        if stddev == 'default':
            self._stddev = 1.
        else:
            self._stddev = stddev

        self._init_learning_rate = init_learning_rate
  
        self._indices = {"batch_size": 0,
                         "num_unrollings": 1,
                         "num_layers": 2,
                         "num_nodes": 3,
                         "depth": 4,
                         "indent": 5,
                         "time_penalty": 6,
                         "half_life": 7,
                         "decay": 8,
                         "num_steps": 9,
                         "averaging_number": 10,
                         "init_mean": 11,
                         "init_stddev": 12,
                         "init_shift": 13,
                         "init_learning_rate": 14,                         
                         "type": 15}
        self._graph = tf.Graph()
        
        self._last_num_steps = 0
        with self._graph.as_default(): 
            with self._graph.device('/gpu:0'): 
                self.Matrix = tf.Variable(tf.truncated_normal([self._vocabulary_size + self._num_nodes[0] + self._depth,
                                                                      4 * self._num_nodes[0]],
                                                                     mean=self._mean, stddev=self._stddev / (self._vocabulary_size + self._num_nodes[0] + self._depth)**0.5))
                self.Bias = tf.Variable(tf.zeros([4 * self._num_nodes[0]]))
                
                self.Halting_Matrix = tf.Variable(tf.truncated_normal([2 * self._num_nodes[0],
                                                                      self._num_nodes[0]],
                                                                     mean=self._mean, stddev=self._stddev / self._num_nodes[0]**0.5))
                
                self.Halting_Bias = tf.Variable(tf.zeros([self._num_nodes[0]]))
                # classifier 
                weights = tf.Variable(tf.truncated_normal([self._num_nodes[-1], self._vocabulary_size], stddev = self._stddev / self._num_nodes[-1]**0.5))
                bias = tf.Variable(tf.zeros([self._vocabulary_size]))
                
                """PLACEHOLDERS train data"""
                self._train_data = list()
                for _ in range(self._num_unrollings + 1):
                    self._train_data.append(
                        tf.placeholder(tf.float32, shape=[self._batch_size, self._vocabulary_size]))
                    
                    
                train_inputs = self._train_data[: self._num_unrollings]
                train_labels = self._train_data[1:]  # labels are inputs shifted by one time step.
                # Unrolled LSTM loop.
                
                """global step"""
                self._global_step = tf.Variable(0, trainable=False)

                saved_state = list()
                saved_state.append(tf.Variable(tf.zeros([self._batch_size, self._num_nodes[0]]), trainable=False))
                saved_state.append(tf.Variable(tf.zeros([self._batch_size, self._num_nodes[0]]), trainable=False))

                outputs = list()
                state = saved_state
                self.number_of_iterations = list()
                first_inputs = list()
                first_outputs = list()
                for i in train_inputs:
                    output, state, prob_loss, number_of_iterations, _, _ = self.iteration(i, state)
                    self.number_of_iterations.append(tf.unpack(number_of_iterations)[0])
                    outputs.append(output)
                    first_inputs.append(tf.split(0, self._batch_size, i)[0])
                    first_outputs.append(tf.split(0, self._batch_size, output)[0])
                self.first_inputs = tf.concat(0, first_inputs)
                self.first_outputs = tf.nn.softmax(tf.nn.xw_plus_b(tf.concat(0, first_outputs), weights, bias))
                self.number_of_iterations = tf.pack(self.number_of_iterations)    

                save_list = list()
                save_list.append(saved_state[0].assign(state[0]))
                save_list.append(saved_state[1].assign(state[1]))
                
                """skip operation"""
                self._skip_operation = tf.group(*save_list)

                with tf.control_dependencies(save_list):
                        # Classifier.
                    logits = tf.nn.xw_plus_b(tf.concat(0, outputs), weights, bias)
                    """loss"""
                    self._loss = tf.reduce_mean(
                        tf.nn.softmax_cross_entropy_with_logits(
                        logits, tf.concat(0, train_labels))) + self._time_penalty * prob_loss / self._num_nodes

                # Optimizer.
                
                """PLACEHOLDERS half life and decay"""
                self._half_life = tf.placeholder(tf.int32)
                self._decay = tf.placeholder(tf.float32)
                """learning rate"""
                self._learning_rate = tf.train.exponential_decay(self._init_learning_rate,
                                                                 self._global_step,
                                                                 self._half_life,
                                                                 self._decay,
                                                                 staircase=True)
                optimizer = tf.train.GradientDescentOptimizer(self._learning_rate)
                gradients, v = zip(*optimizer.compute_gradients(self._loss))
                gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
                """optimizer"""
                self._optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=self._global_step)
                """train prediction"""
                self._train_prediction = tf.nn.softmax(logits)


                # Sampling and validation eval: batch 1, no unrolling.
                # Sampling and validation eval: batch 1, no unrolling.
                saved_sample_state = list()
                saved_sample_state.append(tf.Variable(tf.zeros([1, self._num_nodes[0]]), trainable=False))
                saved_sample_state.append(tf.Variable(tf.zeros([1, self._num_nodes[0]]), trainable=False)) 
                """PLACEHOLDER sample input"""
                self._sample_input = tf.placeholder(tf.float32, shape=[1, self._vocabulary_size])

                reset_list = list()
                reset_list.append(saved_sample_state[0].assign(tf.zeros([1, self._num_nodes[0]])))
                reset_list.append(saved_sample_state[1].assign(tf.zeros([1, self._num_nodes[0]])))

                """reset sample state"""
                self._reset_sample_state = tf.group(*reset_list)

                sample_output, sample_state, _, self.num_iter, self.probs, hu = self.iteration(self._sample_input, saved_sample_state)

                self.halting_units = tf.concat(0, hu)
                sample_save_list = list()
                sample_save_list.append(saved_sample_state[0].assign(sample_state[0]))
                sample_save_list.append(saved_sample_state[1].assign(sample_state[1]))

                with tf.control_dependencies(sample_save_list):
                    """sample prediction"""
                    self._sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, weights, bias)) 
                
                
                """saver"""
                self.saver = tf.train.Saver(max_to_keep=None)
                            
                        
    
    def _generate_metadata(self, half_life, decay, num_averaging_iterations):
        metadata = list()
        metadata.append(self._batch_size)
        metadata.append(self._num_unrollings)   
        metadata.append(self._num_layers)
        metadata.append(self._num_nodes)
        metadata.append(self._depth)
        metadata.append(self._indent)
        metadata.append(self._time_penalty)
        metadata.append(half_life)
        metadata.append(decay)
        metadata.append(self._last_num_steps)
        metadata.append(num_averaging_iterations)
        metadata.append(self._mean)
        metadata.append(self._stddev)
        metadata.append(self._shift)
        metadata.append(self._init_learning_rate)
        metadata.append('ACT_LSTM_individual')
        return metadata

    def get_iterations(self, session, num_strings=10, length=75, start_positions=None):
        self._reset_sample_state.run()
        self._valid_batches = BatchGenerator(self._valid_text,
                                             1,
                                             self._vocabulary_size,
                                             self._characters_positions_in_vocabulary,
                                             1)
        if start_positions is None:
            start_positions = list()
            if self._valid_size / num_strings < length:
                num_strings = self._valid_size / length
            for i in range(num_strings):
                start_positions.append(i* (self._valid_size / num_strings) + self._valid_size / num_strings / 2)
            while self._valid_size - start_positions[-1] < length:
                del start_positions[-1]
        text_list = list()
        iterations_list = list()
        collect_iterations = False
        letters_parsed = -1
        for idx in range(self._valid_size):
            b = self._valid_batches.next()
            
            if idx in start_positions or collect_iterations: 
                if letters_parsed == -1:
                    letters_parsed = 0
                    text = u""
                    i_list = [list() for _ in range(self._num_nodes[0])]
                    collect_iterations = True
                text += characters(b[0], self._vocabulary)[0]
                for_distribution = self.num_iter.eval({self._sample_input: b[0]})
                for node_idx in range(for_distribution.shape[1]):
                    i_list[node_idx].append(for_distribution[0][node_idx])
                letters_parsed += 1
                if letters_parsed >= length:
                    collect_iterations = False
                    iterations_list.append(i_list)
                    text_list.append(text)
                    letters_parsed = -1
                    
            _ = self._sample_prediction.eval({self._sample_input: b[0]})
        return text_list, iterations_list  
    
    def get_average_iterations(self, session, num_strings=10, length=75, start_positions=None):
        self._reset_sample_state.run()
        self._valid_batches = BatchGenerator(self._valid_text,
                                             1,
                                             self._vocabulary_size,
                                             self._characters_positions_in_vocabulary,
                                             1)
        if start_positions is None:
            start_positions = list()
            if self._valid_size / num_strings < length:
                num_strings = self._valid_size / length
            for i in range(num_strings):
                start_positions.append(i* (self._valid_size / num_strings) + self._valid_size / num_strings / 2)
            while self._valid_size - start_positions[-1] < length:
                del start_positions[-1]
        text_list = list()
        iterations_list = list()
        collect_iterations = False
        letters_parsed = -1
        for idx in range(self._valid_size):
            b = self._valid_batches.next()
            
            if idx in start_positions or collect_iterations: 
                if letters_parsed == -1:
                    letters_parsed = 0
                    text = u""
                    i_list = list()
                    collect_iterations = True
                text += characters(b[0], self._vocabulary)[0]
                i_list.append(np.mean(self.num_iter.eval({self._sample_input: b[0]})))
                letters_parsed += 1
                if letters_parsed >= length:
                    collect_iterations = False
                    iterations_list.append(i_list)
                    text_list.append(text)
                    letters_parsed = -1
                    
            _ = self._sample_prediction.eval({self._sample_input: b[0]})
        return text_list, iterations_list

# %%
model = ACT_LSTM_individual(64,
            vocabulary,
            characters_positions_in_vocabulary,
            10,
            [128],
                    5,
                    0.01,
                    0.00003,
            train_text,
            {'html': valid_text_1, 'text': valid_text_2},
            init_learning_rate=0.5)

# %%
print_steps = [1000 * i for i in range(200)]
model.run(10,
          0.9,
            1000,
            50,
            3,
            1,
            100,
          #add_operations = ['self.number_of_iterations'],
          #add_text_operations=['self.first_inputs', 'self.first_outputs'],
          print_steps = print_steps,
          validation_add_operations=['self.probs'],
           #validation_add_operations=['self.num_iter', 'self.probs', 'self.halting_units'],
          #validation_add_operations=['self.num_iter'],
          num_validation_prints=10,
            print_intermediate_results = True,
          validation_example_length=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-28ae8e1e6a3a> in <module>()
#      15           num_validation_prints=10,
#      16             print_intermediate_results = True,
# ---> 17           validation_example_length=10)
#
# /home/rumpelschtizhen/WIKI/model_module.pyc in run(self, num_stairs, decay, train_frequency, min_num_points, stop_percent, num_train_points_per_1_validation_point, averaging_number, optional_feed_dict, print_intermediate_results, half_life_fixed, add_operations, add_text_operations, print_steps, validation_add_operations, num_validation_prints, validation_example_length, fuse_texts)
#     453         config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
#     454         with tf.Session(graph=self._graph, config=config) as session:
# --> 455             tf.initialize_all_variables().run()
#     456             if print_intermediate_results:
#     457                 print('Initialized')
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in run(self, feed_dict, session)
#    1551         none, the default session will be used.
#    1552     """
# -> 1553     _run_using_default_session(self, feed_dict, self.graph, session)
#    1554
#    1555
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _run_using_default_session(operation, feed_dict, graph, session)
#    3682                        "the operation's graph is different from the session's "
#    3683                        "graph.")
# -> 3684   session.run(operation, feed_dict)
#    3685
#    3686
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     380     try:
#     381       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 382                          run_metadata_ptr)
#     383       if run_metadata:
#     384         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     653     movers = self._update_with_movers(feed_dict_string, feed_map)
#     654     results = self._do_run(handle, target_list, unique_fetches,
# --> 655                            feed_dict_string, options, run_metadata)
#     656
#     657     # User may have fetched the same tensor multiple times, but we
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#     721     if handle is None:
#     722       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# --> 723                            target_list, options, run_metadata)
#     724     else:
#     725       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#     728   def _do_call(self, fn, *args):
#     729     try:
# --> 730       return fn(*args)
#     731     except errors.OpError as e:
#     732       message = compat.as_text(e.message)
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#     706                 run_metadata):
#     707       # Ensure any changes to the graph are reflected in the runtime.
# --> 708       self._extend_graph()
#     709       with errors.raise_exception_on_not_ok_status() as status:
#     710         return tf_session.TF_Run(session, options,
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _extend_graph(self)
#     750         graph_def, self._current_version = self._graph._as_graph_def(
#     751             from_version=self._current_version,
# --> 752             add_shapes=self._add_shapes)
#     753         # pylint: enable=protected-access
#     754
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in _as_graph_def(self, from_version, add_shapes)
#    2122         op = self._nodes_by_id[op_id]
#    2123         if from_version is None or op_id > from_version:
# -> 2124           graph.node.extend([op.node_def])
#    2125           if op.outputs and add_shapes:
#    2126             assert "_output_shapes" not in graph.node[-1].attr
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/google/protobuf/internal/containers.pyc in extend(self, elem_seq)
#     385     values = self._values
#     386     for message in elem_seq:
# --> 387       new_element = message_class()
#     388       new_element._SetListener(listener)
#     389       new_element.MergeFrom(message)
#
# /home/rumpelschtizhen/.local/lib/python2.7/site-packages/google/protobuf/internal/python_message.pyc in init(self, **kwargs)
#     485     self._is_present_in_parent = False
#     486     self._listener = message_listener_mod.NullMessageListener()
# --> 487     self._listener_for_children = _Listener(self)
#     488     for field_name, field_value in kwargs.items():
#     489       field = _GetFieldByName(message_descriptor, field_name)
#
# KeyboardInterrupt:

# %%
model.simple_run(200,
                   'ACT_LSTM_individual/variables/first_try_idt0.01_mf0.00003',
                   10000,
                   400,
                   5000,        #learning has a chance to be stopped after every block of steps
                   20,
                   0.9,
                   3,
                   fixed_num_steps=True)
# Out:
# Number of steps = 10000     Percentage = 39.92%     Time = 1453s     Learning rate = 0.0608

# %%
from plot_module import vocabulary_gates_plots
model = ACT_LSTM_individual(64,
            vocabulary,
            characters_positions_in_vocabulary,
            10,
            [128],
                    5,
                    0.01,
                    0.001,
            train_text,
            valid_text, 
            init_learning_rate=0.5)
text_list, iter_list = model.run_for_analitics(model.get_iterations,
                                                        'ACT_LSTM_individual/variables/first_try_idt0.01_mf0.00003',
                                                        [300, 75, None])

vocabulary_gates_plots(text_list,
                               iter_list,
                               'figure_title',
                              ['ACT_LSTM_individual', 'folder_list'],
                               'vocabulary_gates_plots',
                               max_num_words_per_length=100,
                               vmin=1.,
                            vmax=5.,
                           error_threshold=0.5,
                               show=False)
text_list, average_list = model.run_for_analitics(model.get_average_iterations,
                                                        'ACT_LSTM_individual/variables/first_try_idt0.01_mf0.00003',
                                                        [300, 75, None])
structure_vocabulary_plots(text_list,
                                   average_list,
                                   'figure_title',
                                   'iterations',
                                   ['ACT_LSTM_individual', 'folder_list'],
                                   'structure_vocabulary_plots',
                                   ylims = [1., 5.],
                                   ylims_fixed=True,
                                   show=False)

# %%
sttdev_values = [.01, .05, .2, 1., 5., 10., 25.]
init_learning_rate_values = [15., 10., 5., 2.5, 1., 0.5, .25, .1, .05, .02, .01]
adjustment_results = list()
for learning_rate in init_learning_rate_values:
    print(' '*10, 'learning_rate:', learning_rate)
    for stddev_value in sttdev_values:
        print(' '*5, 'stddev:', stddev_value)
        model = ACT_LSTM_individual(64,
                         vocabulary,
                         characters_positions_in_vocabulary,
                         10,
                         [128],
                         5,
                         0.01,
                         0.0003,
                         train_text,
                         valid_text_1,
                         stddev=stddev_value,
                         init_learning_rate=learning_rate) 
        model.simple_run(200,
                         'ACT_LSTM_individual/variables/adjustment_nl1_nn128/ilr%s_stddev%s' % (learning_rate, stddev_value),
                         5000,
                         250,
                         5000,        #learning has a chance to be stopped after every block of steps
                         10,
                         0.9,
                         3,
                         fixed_num_steps=True) 
        adjustment_results.extend(model._results)
        model.destroy()
        del model
        gc.collect()
# Out:
#            learning_rate: 15.0
#       stddev: 0.01
# Number of steps = 5000     Percentage = 50.61%     Time = 719s     Learning rate = 5.2302
#       stddev: 0.05
# Number of steps = 5000     Percentage = 46.92%     Time = 717s     Learning rate = 5.2302
#       stddev: 0.2
# Number of steps = 5000     Percentage = 48.85%     Time = 719s     Learning rate = 5.2302
#       stddev: 1.0
# Number of steps = 5000     Percentage = 50.06%     Time = 720s     Learning rate = 5.2302
#       stddev: 5.0
# Number of steps = 5000     Percentage = 48.44%     Time = 724s     Learning rate = 5.2302
#       stddev: 10.0
# Number of steps = 5000     Percentage = 47.90%     Time = 722s     Learning rate = 5.2302
#       stddev: 25.0
# Number of steps = 5000     Percentage = 42.71%     Time = 731s     Learning rate = 5.2302
#            learning_rate: 10.0
#       stddev: 0.01
# Number of steps = 5000     Percentage = 50.16%     Time = 731s     Learning rate = 3.4868
#       stddev: 0.05
# Number of steps = 5000     Percentage = 50.30%     Time = 731s     Learning rate = 3.4868
#       stddev: 0.2
# Number of steps = 5000     Percentage = 50.41%     Time = 731s     Learning rate = 3.4868
#       stddev: 1.0
# Number of steps = 5000     Percentage = 50.23%     Time = 727s     Learning rate = 3.4868
#       stddev: 5.0
# Number of steps = 5000     Percentage = 49.59%     Time = 732s     Learning rate = 3.4868
#       stddev: 10.0
# Number of steps = 5000     Percentage = 47.62%     Time = 732s     Learning rate = 3.4868
#       stddev: 25.0
# Number of steps = 5000     Percentage = 40.30%     Time = 730s     Learning rate = 3.4868
#            learning_rate: 5.0
#       stddev: 0.01
# Number of steps = 5000     Percentage = 48.31%     Time = 731s     Learning rate = 1.7434
#       stddev: 0.05
# Number of steps = 5000     Percentage = 48.31%     Time = 731s     Learning rate = 1.7434
#       stddev: 0.2
# Number of steps = 5000     Percentage = 48.88%     Time = 730s     Learning rate = 1.7434
#       stddev: 1.0
# Number of steps = 5000     Percentage = 49.63%     Time = 730s     Learning rate = 1.7434
#       stddev: 5.0
# Number of steps = 5000     Percentage = 49.04%     Time = 729s     Learning rate = 1.7434
#       stddev: 10.0
# Number of steps = 5000     Percentage = 46.61%     Time = 730s     Learning rate = 1.7434
#       stddev: 25.0
# Number of steps = 5000     Percentage = 34.45%     Time = 731s     Learning rate = 1.7434
#            learning_rate: 2.5
#       stddev: 0.01
# Number of steps = 5000     Percentage = 43.65%     Time = 731s     Learning rate = 0.8717
#       stddev: 0.05
# Number of steps = 5000     Percentage = 44.66%     Time = 732s     Learning rate = 0.8717
#       stddev: 0.2
# Number of steps = 5000     Percentage = 45.86%     Time = 731s     Learning rate = 0.8717
#       stddev: 1.0
# Number of steps = 5000     Percentage = 47.25%     Time = 730s     Learning rate = 0.8717
#       stddev: 5.0
# Number of steps = 5000     Percentage = 47.20%     Time = 732s     Learning rate = 0.8717
#       stddev: 10.0
# Number of steps = 5000     Percentage = 44.54%     Time = 730s     Learning rate = 0.8717
#       stddev: 25.0
# Number of steps = 5000     Percentage = 31.41%     Time = 727s     Learning rate = 0.8717
#            learning_rate: 1.0
#       stddev: 0.01
# Number of steps = 5000     Percentage = 35.41%     Time = 729s     Learning rate = 0.3487
#       stddev: 0.05
# Number of steps = 5000     Percentage = 37.58%     Time = 731s     Learning rate = 0.3487
#       stddev: 0.2
# Number of steps = 5000     Percentage = 39.07%     Time = 731s     Learning rate = 0.3487
#       stddev: 1.0
# Number of steps = 5000     Percentage = 42.94%     Time = 729s     Learning rate = 0.3487
#       stddev: 5.0
# Number of steps = 5000     Percentage = 44.41%     Time = 729s     Learning rate = 0.3487
#       stddev: 10.0
# Number of steps = 5000     Percentage = 40.60%     Time = 731s     Learning rate = 0.3487
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.43%     Time = 731s     Learning rate = 0.3487
#            learning_rate: 0.5
#       stddev: 0.01
# Number of steps = 5000     Percentage = 25.90%     Time = 716s     Learning rate = 0.1743
#       stddev: 0.05
# Number of steps = 5000     Percentage = 27.90%     Time = 726s     Learning rate = 0.1743
#       stddev: 0.2
# Number of steps = 5000     Percentage = 32.72%     Time = 715s     Learning rate = 0.1743
#       stddev: 1.0
# Number of steps = 5000     Percentage = 38.82%     Time = 728s     Learning rate = 0.1743
#       stddev: 5.0
# Number of steps = 5000     Percentage = 41.16%     Time = 730s     Learning rate = 0.1743
#       stddev: 10.0
# Number of steps = 5000     Percentage = 37.47%     Time = 729s     Learning rate = 0.1743
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.39%     Time = 730s     Learning rate = 0.1743
#            learning_rate: 0.25
#       stddev: 0.01
# Number of steps = 5000     Percentage = 14.97%     Time = 729s     Learning rate = 0.0872
#       stddev: 0.05
# Number of steps = 5000     Percentage = 20.12%     Time = 731s     Learning rate = 0.0872
#       stddev: 0.2
# Number of steps = 5000     Percentage = 24.51%     Time = 727s     Learning rate = 0.0872
#       stddev: 1.0
# Number of steps = 5000     Percentage = 33.45%     Time = 726s     Learning rate = 0.0872
#       stddev: 5.0
# Number of steps = 5000     Percentage = 37.77%     Time = 727s     Learning rate = 0.0872
#       stddev: 10.0
# Number of steps = 5000     Percentage = 34.22%     Time = 730s     Learning rate = 0.0872
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.50%     Time = 726s     Learning rate = 0.0872
#            learning_rate: 0.1
#       stddev: 0.01
# Number of steps = 5000     Percentage = 13.50%     Time = 728s     Learning rate = 0.0349
#       stddev: 0.05
# Number of steps = 5000     Percentage = 13.50%     Time = 727s     Learning rate = 0.0349
#       stddev: 0.2
# Number of steps = 5000     Percentage = 13.50%     Time = 731s     Learning rate = 0.0349
#       stddev: 1.0
# Number of steps = 5000     Percentage = 24.59%     Time = 729s     Learning rate = 0.0349
#       stddev: 5.0
# Number of steps = 5000     Percentage = 33.02%     Time = 717s     Learning rate = 0.0349
#       stddev: 10.0
# Number of steps = 5000     Percentage = 28.91%     Time = 728s     Learning rate = 0.0349
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.45%     Time = 727s     Learning rate = 0.0349
#            learning_rate: 0.05
#       stddev: 0.01
# Number of steps = 5000     Percentage = 13.50%     Time = 727s     Learning rate = 0.0174
#       stddev: 0.05
# Number of steps = 5000     Percentage = 13.50%     Time = 730s     Learning rate = 0.0174
#       stddev: 0.2
# Number of steps = 5000     Percentage = 13.50%     Time = 727s     Learning rate = 0.0174
#       stddev: 1.0
# Number of steps = 5000     Percentage = 16.66%     Time = 729s     Learning rate = 0.0174
#       stddev: 5.0
# Number of steps = 5000     Percentage = 29.82%     Time = 726s     Learning rate = 0.0174
#       stddev: 10.0
# Number of steps = 5000     Percentage = 24.30%     Time = 727s     Learning rate = 0.0174
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.43%     Time = 728s     Learning rate = 0.0174
#            learning_rate: 0.02
#       stddev: 0.01
# Number of steps = 5000     Percentage = 13.50%     Time = 727s     Learning rate = 0.0070
#       stddev: 0.05
# Number of steps = 5000     Percentage = 13.50%     Time = 728s     Learning rate = 0.0070
#       stddev: 0.2
# Number of steps = 5000     Percentage = 13.50%     Time = 731s     Learning rate = 0.0070
#       stddev: 1.0
# Number of steps = 5000     Percentage = 13.50%     Time = 725s     Learning rate = 0.0070
#       stddev: 5.0
# Number of steps = 5000     Percentage = 23.23%     Time = 728s     Learning rate = 0.0070
#       stddev: 10.0
# Number of steps = 5000     Percentage = 16.22%     Time = 730s     Learning rate = 0.0070
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.51%     Time = 728s     Learning rate = 0.0070
#            learning_rate: 0.01
#       stddev: 0.01
# Number of steps = 5000     Percentage = 13.50%     Time = 725s     Learning rate = 0.0035
#       stddev: 0.05
# Number of steps = 5000     Percentage = 13.50%     Time = 726s     Learning rate = 0.0035
#       stddev: 0.2
# Number of steps = 5000     Percentage = 13.50%     Time = 726s     Learning rate = 0.0035
#       stddev: 1.0
# Number of steps = 5000     Percentage = 13.50%     Time = 725s     Learning rate = 0.0035
#       stddev: 5.0
# Number of steps = 5000     Percentage = 19.28%     Time = 729s     Learning rate = 0.0035
#       stddev: 10.0
# Number of steps = 5000     Percentage = 0.85%     Time = 727s     Learning rate = 0.0035
#       stddev: 25.0
# Number of steps = 5000     Percentage = 0.48%     Time = 727s     Learning rate = 0.0035

# %%
folder_name = 'ACT_LSTM_individual'
file_name = 'ACT_LSTM_individual_adjustment_ns_5000_hl_500_dc_0.9_nu_10_ilr15._.01_std0.01-25.pickle'
force = True
pickle_dump = {'adjustment_results': adjustment_results}
if not os.path.exists(folder_name):
    try:
        os.makedirs(folder_name)
    except Exception as e:
        print("Unable create folder '%s'" % folder_name, ':', e)    
print('Pickling %s.' % (folder_name + '/' + file_name))
try:
    with open(folder_name + '/' + file_name, 'wb') as f:
        pickle.dump(pickle_dump, f, pickle.HIGHEST_PROTOCOL)
except Exception as e:
    print('Unable to save data to', file_name, ':', e)
# Out:
# Pickling ACT_LSTM_individual/ACT_LSTM_individual_adjustment_ns_5000_hl_500_dc_0.9_nu_10_ilr15._.01_std0.01-25.pickle.

# %%
folder_name = 'ACT_LSTM_individual'
pickle_file = 'ACT_LSTM_individual_adjustment_ns_5000_hl_500_dc_0.9_nu_10_ilr15._.01_std0.01-25.pickle'

with open(folder_name + '/' + pickle_file, 'rb') as f:
  save = pickle.load(f)
  adjustment_results = save['adjustment_results']
  del save  # hint to help gc free up memory

# %%
from plot_module import ComparePlots

ACT_LSTM_adjustment_plots = ComparePlots('ACT_LSTM_individual')
ACT_LSTM_adjustment_plots.add_network(adjustment_results, model._indices)

# %%
plot_options = {'x': 'log'}
plot_data, _ = ACT_LSTM_adjustment_plots.one_key_layout_data('ACT_LSTM_individual_1',
                                                             "init_learning_rate",
                                                            'init_stddev')
ACT_LSTM_adjustment_plots.save_layout(plot_data[0],
                    'initial learning rate',
                    ['adjustment'],
                    'init_learning_rate_nn128;ns5000;hl500;dc0.9',
                     plot_options=plot_options)
ACT_LSTM_adjustment_plots.draw(plot_data[0], 'initial learning rate', plot_options=plot_options)
# Out:
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plot_options = {'x': 'log'}
plot_data, _ = ACT_LSTM_adjustment_plots.one_key_layout_data('ACT_LSTM_individual_1',
                                                                'init_stddev',
                                         "init_learning_rate")
ACT_LSTM_adjustment_plots.save_layout(plot_data[0],
                    'matrices initialization',
                    ['adjustment'],
                    'matrices_initialization_nn128;ns5000;hl500;dc0.9',
                     plot_options=plot_options)
ACT_LSTM_adjustment_plots.draw(plot_data[0], 'matrices initialization', plot_options=plot_options)
# Out:
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']

# %%
num_unrollings_value = 20
# .5, .25, .1, .05, .02, .01, .005, .002, .001, .0003, 
#.5, .25, .1, .05, .02, .01,
indent_values = [ .005, .002, .001, .0003, .0001, .00001, .000001, .0]
time_penalty_values = [0.,
                       .000001,
                       .000003,
                       .00001,
                       .00003,
                       .0001,
                       .0003,
                       .001,
                       .003,
                       .01,
                       .03,
                       .1]
results_GL = list()

for indent_value in indent_values:
    print(' '*4, "indent: ", indent_value)
    for time_penalty_value in time_penalty_values:
        print(' '*2, "time penalty: ", time_penalty_value)
        model = ACT_LSTM_individual(64,
                                                vocabulary,
                                                characters_positions_in_vocabulary,
                                             num_unrollings_value,            #number of memory layers
                                             [128],
                    5,
                    indent_value,
                    time_penalty_value,
            train_text,
            valid_text_2)
        model.simple_run(100,
                                       'ACT_LSTM_individual/variables/nn128_dth_5_nu20_bs64_ilr10_hl500_ns20000/idt%s_tp%s' %
                                     (indent_value, time_penalty_value),
                                       20000,
                                       4000,
                                       5000,        #learning has a chance to be stopped after every block of steps
                                       40,
                                       0.9,
                                       3,
                                     fixed_num_steps=True)
        results_GL.extend(model._results)
        model.destroy()
        del model
        gc.collect()
# Out:
#      indent:  0.005
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.38%     Time = 6176s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.53%     Time = 6242s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.44%     Time = 6194s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.50%     Time = 6228s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.53%     Time = 6203s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.67%     Time = 6220s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.46%     Time = 6200s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.62%     Time = 6119s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.97%     Time = 6113s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.87%     Time = 6108s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.82%     Time = 6116s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 50.44%     Time = 6130s     Learning rate = 0.0739
#      indent:  0.002
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.76%     Time = 6128s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.45%     Time = 6103s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.49%     Time = 6042s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.57%     Time = 5704s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.55%     Time = 5880s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.72%     Time = 5895s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.43%     Time = 5903s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.54%     Time = 5873s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.87%     Time = 5805s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 51.39%     Time = 5785s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.60%     Time = 5800s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 50.37%     Time = 5769s     Learning rate = 0.0739
#      indent:  0.001
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.53%     Time = 5767s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.96%     Time = 5815s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.64%     Time = 6111s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.49%     Time = 6104s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.74%     Time = 6101s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.34%     Time = 6068s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.27%     Time = 6111s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.62%     Time = 6111s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.91%     Time = 6104s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.80%     Time = 6107s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.49%     Time = 6107s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.95%     Time = 6109s     Learning rate = 0.0739
#      indent:  0.0003
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.63%     Time = 6085s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.74%     Time = 6080s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.42%     Time = 6224s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.36%     Time = 6200s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.76%     Time = 6230s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.42%     Time = 6228s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.49%     Time = 6231s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.40%     Time = 6224s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.81%     Time = 6180s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.67%     Time = 6090s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.14%     Time = 6239s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.34%     Time = 6220s     Learning rate = 0.0739
#      indent:  0.0001
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.57%     Time = 6225s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.75%     Time = 6230s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.69%     Time = 6214s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.60%     Time = 6192s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.63%     Time = 6207s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.67%     Time = 6237s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.42%     Time = 6229s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.59%     Time = 6239s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.79%     Time = 6218s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.77%     Time = 6193s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.09%     Time = 6227s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.33%     Time = 6224s     Learning rate = 0.0739
#      indent:  1e-05
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.62%     Time = 6224s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.40%     Time = 6230s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.64%     Time = 6218s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.48%     Time = 6153s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.63%     Time = 6074s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.55%     Time = 6117s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.60%     Time = 6109s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.55%     Time = 6219s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 51.97%     Time = 6237s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 51.01%     Time = 6244s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.29%     Time = 6244s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.42%     Time = 6247s     Learning rate = 0.0739
#      indent:  1e-06
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.86%     Time = 6230s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.57%     Time = 6151s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.68%     Time = 6225s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.66%     Time = 6126s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.46%     Time = 6122s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.60%     Time = 6217s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.36%     Time = 6175s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.52%     Time = 6138s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 52.29%     Time = 6202s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.43%     Time = 6241s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.01%     Time = 6235s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.61%     Time = 6200s     Learning rate = 0.0739
#      indent:  0.0
#    time penalty:  0.0
# Number of steps = 20000     Percentage = 54.59%     Time = 6208s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 20000     Percentage = 54.73%     Time = 6215s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 20000     Percentage = 54.62%     Time = 6228s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 20000     Percentage = 54.64%     Time = 6235s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 20000     Percentage = 54.63%     Time = 6153s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 20000     Percentage = 54.94%     Time = 6068s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 20000     Percentage = 54.47%     Time = 6139s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 20000     Percentage = 53.51%     Time = 6244s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 20000     Percentage = 52.08%     Time = 6249s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 20000     Percentage = 50.81%     Time = 6253s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 20000     Percentage = 50.11%     Time = 6229s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 20000     Percentage = 49.44%     Time = 6248s     Learning rate = 0.0739

# %%
# .5, .25, .1, .05, .02, .01, .005, .002, .001, .0003, 
#.5, .25, .1, .05, .02, .01,
num_unrollings_value = 20
indent_values = [.5, .25, .1, .05, .02, .01, .005, .002, .001, .0003, .0001, .00001, .000001, .0]
time_penalty_values = [0.,
                       .000001,
                       .000003,
                       .00001,
                       .00003,
                       .0001,
                       .0003,
                       .001,
                       .003,
                       .01,
                       .03,
                       .1]

results_GL = list()

for indent_value in indent_values:
    print(' '*4, "indent: ", indent_value)
    for time_penalty_value in time_penalty_values:
        print(' '*2, "time penalty: ", time_penalty_value)
        
        model = ACT_LSTM_individual(64,
                                                        vocabulary,
                                                        characters_positions_in_vocabulary,
                                                     num_unrollings_value,            #number of memory layers
                                                     [128],
                            5,
                            indent_value,
                            time_penalty_value,
                    train_text,
                    valid_text_2)
        save_path = 'ACT_LSTM_individual/variables/nn128_dth_5_nu20_bs64_ilr10_hl500_ns20000/idt%s_tp%s' % (indent_value, time_penalty_value)
        model.get_result(save_path,
                             200,
                   20000,
                   40,
                   0.9,
                        fixed_num_steps=True)
        results_GL.extend(model._results)
        model.destroy()
        del model
# Out:
#      indent:  0.5
#    time penalty:  0.0
# Number of steps = 0     Percentage = 53.69%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 53.66%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 53.52%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 53.60%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 53.60%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 53.49%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 53.48%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.40%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 53.21%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 53.36%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 52.97%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 52.96%     Time = 0s     Learning rate = 0.0739
#      indent:  0.25
#    time penalty:  0.0
# Number of steps = 0     Percentage = 54.41%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.55%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.25%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.26%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.37%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.35%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 53.95%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.74%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.94%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 53.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 52.76%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 52.41%     Time = 0s     Learning rate = 0.0739
#      indent:  0.1
#    time penalty:  0.0
# Number of steps = 0     Percentage = 54.68%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.72%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.82%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.59%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.75%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.75%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.51%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.97%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.91%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 52.58%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 52.38%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 51.89%     Time = 0s     Learning rate = 0.0739
#      indent:  0.05
#    time penalty:  0.0
# Number of steps = 0     Percentage = 54.84%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.88%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.79%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 55.13%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.89%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.72%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.55%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.82%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 53.07%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 52.16%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 52.04%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 51.51%     Time = 0s     Learning rate = 0.0739
#      indent:  0.02
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.01%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.00%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.98%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.99%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.01%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.86%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.62%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.18%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.71%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.62%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 51.68%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 51.29%     Time = 0s     Learning rate = 0.0739
#      indent:  0.01
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.05%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.09%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.92%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.91%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.05%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.15%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.71%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.68%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.44%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.66%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 51.29%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 50.99%     Time = 0s     Learning rate = 0.0739
#      indent:  0.005
#    time penalty:  0.0
# Number of steps = 0     Percentage = 54.90%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.97%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.87%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.95%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.99%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.95%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.42%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.31%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 51.08%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 50.75%     Time = 0s     Learning rate = 0.0739
#      indent:  0.002
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.15%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.99%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.87%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 55.03%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.99%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.20%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.90%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.97%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.46%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.71%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 51.08%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 50.67%     Time = 0s     Learning rate = 0.0739
#      indent:  0.001
#    time penalty:  0.0
# Number of steps = 0     Percentage = 54.91%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.29%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.01%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.92%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.14%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.90%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.78%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.17%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.30%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.05%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.89%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 50.27%     Time = 0s     Learning rate = 0.0739
#      indent:  0.0003
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.09%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.10%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 54.88%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.89%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.97%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 54.77%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.96%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 53.82%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.32%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.06%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.69%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 49.77%     Time = 0s     Learning rate = 0.0739
#      indent:  0.0001
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.04%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.10%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.21%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 55.00%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.09%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.12%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.92%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.14%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.18%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.18%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.47%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 49.69%     Time = 0s     Learning rate = 0.0739
#      indent:  1e-05
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.01%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 54.94%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.06%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 54.99%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.10%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 55.00%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.09%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.31%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.25%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.64%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 49.75%     Time = 0s     Learning rate = 0.0739
#      indent:  1e-06
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.17%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.04%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.17%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 55.19%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 54.98%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.80%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.02%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.68%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 50.92%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.42%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 50.09%     Time = 0s     Learning rate = 0.0739
#      indent:  0.0
#    time penalty:  0.0
# Number of steps = 0     Percentage = 55.05%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-06
# Number of steps = 0     Percentage = 55.10%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-06
# Number of steps = 0     Percentage = 55.17%     Time = 0s     Learning rate = 0.0739
#    time penalty:  1e-05
# Number of steps = 0     Percentage = 55.03%     Time = 0s     Learning rate = 0.0739
#    time penalty:  3e-05
# Number of steps = 0     Percentage = 55.11%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0001
# Number of steps = 0     Percentage = 55.09%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.0003
# Number of steps = 0     Percentage = 54.86%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.001
# Number of steps = 0     Percentage = 54.04%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.003
# Number of steps = 0     Percentage = 52.47%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.01
# Number of steps = 0     Percentage = 51.30%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.03
# Number of steps = 0     Percentage = 50.50%     Time = 0s     Learning rate = 0.0739
#    time penalty:  0.1
# Number of steps = 0     Percentage = 49.77%     Time = 0s     Learning rate = 0.0739

# %%
folder_name = 'ACT_LSTM_individual'
file_name = 'ACT_LSTM_individual_ns_20000_hl_500_dc_0.9_nu_20_idt0.5_0_tp0.1_0.0.pickle'
force = True
pickle_dump = {'results_GL': results_GL}
if not os.path.exists(folder_name):
    try:
        os.makedirs(folder_name)
    except Exception as e:
        print("Unable create folder '%s'" % folder_name, ':', e)    
print('Pickling %s.' % (folder_name + '/' + file_name))
try:
    with open(folder_name + '/' + file_name, 'wb') as f:
        pickle.dump(pickle_dump, f, pickle.HIGHEST_PROTOCOL)
except Exception as e:
    print('Unable to save data to', file_name, ':', e)
# Out:
# Pickling ACT_LSTM_individual/ACT_LSTM_individual_ns_20000_hl_500_dc_0.9_nu_20_idt0.5_0_tp0.1_0.0.pickle.

# %%
folder_name = 'ACT_LSTM_individual'
pickle_file = 'ACT_LSTM_individual_ns_20000_hl_500_dc_0.9_nu_20_idt0.5_0_tp0.1_0.0.pickle'

with open(folder_name + '/' + pickle_file, 'rb') as f:
  save = pickle.load(f)
  results_GL = save['results_GL']
  del save  # hint to help gc free up memory

# %%
from plot_module import ComparePlots

ACT_LSTM_individual_plots = ComparePlots('ACT_LSTM_individual')
ACT_LSTM_individual_plots.add_network(results_GL, model._indices)

# %%
plot_options = {'x': 'log'}
plot_data, _ = ACT_LSTM_individual_plots.one_key_layout_data('ACT_LSTM_individual_1',
                                         'time_penalty',
                                                       'indent')
ACT_LSTM_individual_plots.save_layout(plot_data[0],
                    'time penalty effect',
                    ['plots'],
                    'tp_eff_nl1;nn128;ns20000;hl500;dc0.9',
                           plot_options=plot_options)
ACT_LSTM_individual_plots.draw(plot_data[0], 'time penalty effect', plot_options=plot_options)
# Out:
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1288: UserWarning: findfont: Font family [u'normal'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plot_options = {'x': 'log'}
plot_data, _ = ACT_LSTM_individual_plots.one_key_layout_data('ACT_LSTM_individual_1',
                                         'indent',
                                                       'time_penalty')
ACT_LSTM_individual_plots.save_layout(plot_data[0],
                    'indent effect',
                    ['plots'],
                    'idt_eff_nl1;nn128;ns20000;hl500;dc0.9',
                           plot_options=plot_options)
ACT_LSTM_individual_plots.draw(plot_data[0], 'indent effect', plot_options=plot_options)
# Out:
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']
# ['init_shift', 'init_mean', 'batch_size', 'half_life', 'init_stddev', 'num_layers', 'num_unrollings', 'indent', 'decay', 'averaging_number', 'num_steps', 'num_nodes', 'depth', 'init_learning_rate', 'time_penalty', 'type']

# %%
num_unrollings_value = 20
indent_values = [.25, .03, .003, .0003]
time_penalty_values = [.1, .03, .01, 0.003, .001, 0.0003, 0.0001]

results_GL = list()

for indent_value in indent_values:
    print(' '*4, "indent: ", indent_value)
    for time_penalty_value in time_penalty_values:
        print(' '*2, "time penalty: ", time_penalty_value)
        model = ACT_LSTM(64,
                                                vocabulary,
                                                characters_positions_in_vocabulary,
                                             num_unrollings_value,            #number of memory layers
                                             [128],
                    5,
                    indent_value,
                    time_penalty_value,
            train_text,
            valid_text,
            init_learning_rate=10.)
        text_list, iter_list = model.run_for_analitics(model.get_iterations,
                                                        'ACT_LSTM_individual/variables/nn128_dth_5_nu20_bs64_ilr10_hl500_ns20000/idt%s_tp%s' % (indent_value, time_penalty_value),
                                                        [300, 75, None])
        """check_text = ''
        check_text = check_text.join(text_list)
        count_words(check_text)"""

        structure_vocabulary_plots(text_list,
                                   iter_list,
                                   'iterations (indent: %s; time penalty: %s)' % (indent_value, time_penalty_value),
                                   'iterations',
                                   ['ACT_LSTM_individual', 'iterations', 'vocabulary_plots'],
                                   'ns20k_idt%s_tp%s' % (indent_value, time_penalty_value),
                                   ylims = [1., 5.],
                                   ylims_fixed=True,
                                   show=False)
        for i in range(50):
            text_plot(text_list[i],
                      iter_list[i],
                      'iterations',
                      'iterations (indent: %s; time penalty: %s)' % (indent_value, time_penalty_value),
                      ['ACT_LSTM_individual', 'text_plots', 'ns20k_nn128', 'idt%s_tp%s' % (indent_value, time_penalty_value)],
                      'ns20k_idt%s_tp%s#%s' % (indent_value, time_penalty_value, i),
                      ylims=[1., 5.],
                      show=False)
        model.destroy()
        del model
        gc.collect()
